# %% [markdown]
# <a href="https://colab.research.google.com/github/she-codesstuff/python-mastery-goal-1/blob/main/Pythonsession.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Python Output
## Python is a case sensitive language
print("hello world")
# Out:
# hello world

# %%
print(7)
print(7.8)
# Out:
# 7
# 7.8

# %%
print("hello",2,4.5,True) ## can print many things at once
# Out:
# hello 2 4.5 True

# %%
print("hello",2,4.5,True, sep = "!")
# Out:
# hello!2!4.5!True

# %%
print("hello")
print("world")
# Out:
# hello
# world

# %%
print("hello",end ="-" )
print("world")
# Out:
# hello-world

# %% [markdown]
# **Data Types**

# %%
## Integer
print(8)
print(1e308)
print(1e309) ## cannot handle after this number
# Out:
# 8
# 1e+308
# inf

# %%
## Decimal

print(4.6)
print(1.7e309)
# Out:
# 4.6
# inf

# %%
## Boolean

print(True)
print(False)
# Out:
# True
# False

# %%
# Text/String
print("Hello world")
# Out:
# Hello world

# %%
# Complex Number
print(5+6j)
print(1e379+20j)
# Out:
# (5+6j)
# (inf+20j)

# %%
# List as in c array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#Dictionary
print({'name':'Geetha','gender':'Female','weight':50})
# Out:
# {'name': 'Geetha', 'gender': 'Female', 'weight': 50}

# %%
type(3)
# Out:
# int

# %% [markdown]
# **Variables**

# %%
a = 12
print(a)
# Out:
# 12

# %%
a,b,c = 1,2,3
print(a,b,c)
a = b = c = 5
print(a,b,c)
# Out:
# 1 2 3
# 5 5 5

# %% [markdown]
# **Keywords and Identifiers**

# %%
# Identifiers
# You cant start with a digit
name1= 'Nitish'
print(name1)
#you can use only _
_ = 10
print(_)
# identifiers cant be a keyword
# Out:
# Nitish
# 10

# %% [markdown]
# **User Input**

# %%
# Static VS Dynamic
input("Say your name ")

# %%
from re import S
from enum import StrEnum
# Take input from users and store them in a variable
fnum = input("Enter First number")
Snum = input("Enter Second number")
print(fnum,Snum)
# add the 2 variables
result = int(fnum)+int(Snum)
# print the result
print(result)
# the datatype is string,string is a universal format
print(type(fnum))
# doesnot changes the original data it operates on new memory created
#  type will be string only

# %%
fnum = int(input("Enter First number"))

# %% [markdown]
# Type Conversion

# %%
# Implicit vs explicit
print(4+4.4)
print(type(4),type(4.4))

# %%
# Explicit
# com to int
int(4+5j)
# str to int
int(4.4)
# int to str
str(5)

# float
float(4)

# %% [markdown]
# Literals

# %%
# value of the variables
a = 0b1010 #Binary Literals and 0B is binary
b = 100 #Decimal Literal
c = 0o310 #Octal Literal is 0o is octal
d = 0x12c #Hexadecimal Literal and 0x is hexa

#Float Literal
float_1 = 10.5
float_2 = 1.5e2 # 1.5 *10^2
float_3 = 1.5e-3 # 1.5 *10^-3

#Complex Literal
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag,x.real)

# %%
x =3.14j
print(x)
print(x.imag)
print(x.real)

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f603
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)

# %%
a = True + 4
b = False + 10

print("a:", a)
print("b:", b)

# %%
a = None
print(a)

# %% [markdown]
# Operators

# %%
# Arithematic,relational,logical,

# %%
echo "# python-mastery-goal-1" >> README.md
git init
git add README.md
git commit -m "first commit"
git branch -M main
git remote add origin https://github.com/she-codesstuff/python-mastery-goal-1.git
git push -u origin main
